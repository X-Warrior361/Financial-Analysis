# %%
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime

# %%
data_2022 = pd.read_csv("equity_data_2022.csv")
data_2020 = pd.read_csv("equity_data_2020.csv")

# %%
data_2020.columns = data_2020.columns.str.lower()
data_2022.columns = data_2022.columns.str.lower()
data_2020 = data_2020.drop(['series'], axis=1)
data_2020 = data_2020.rename(columns={'date1': 'date'})
data_2022 = data_2022.rename(columns={'date1': 'date'})

data_2020.date = pd.to_datetime(data_2020.date)
data_2022.date = pd.to_datetime(data_2022.date)
# Out:
# C:\Users\X Warrior\AppData\Local\Temp\ipykernel_9700\30130347.py:8: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   data_2022.date = pd.to_datetime(data_2022.date)

# %%
data_2022.describe()
# Out:
#           prev_close     open_price     high_price      low_price  \
# count  990833.000000  990833.000000  990833.000000  990833.000000
# mean      674.849432     676.747257     688.647452     664.035085
# std      2697.695191    2702.883534    2739.475977    2663.240806
# min         0.050000       0.050000       0.100000       0.050000
# 25%        47.250000      47.600000      48.800000      46.100000
# 50%       154.590000     155.200000     159.000000     151.350000
# 75%       499.500000     501.000000     512.000000     490.050000
# max     96973.850000   96770.000000   98599.950000   92750.000000
#
#           last_price    close_price      avg_price  ttl_trd_qnty  \
# count  990833.000000  990833.000000  990833.000000  9.908330e+05
# mean      675.202972     675.197884     676.274338  1.756849e+06
# std      2698.009807    2698.672629    2700.817873  1.641392e+07
# min         0.050000       0.050000       0.000000  1.000000e+00
# ...

# %%
data_2020.describe()
# Out:
#          prev_close    open_price    high_price     low_price    last_price  \
# count  1.408943e+06  1.408943e+06  1.408943e+06  1.408943e+06  1.408943e+06
# mean   6.840059e+02  6.858212e+02  6.971527e+02  6.737319e+02  4.511247e+02
# std    2.754809e+03  2.759858e+03  2.794694e+03  2.722107e+03  2.265768e+03
# min    5.000000e-02  5.000000e-02  1.000000e-01  5.000000e-02  0.000000e+00
# 25%    5.155000e+01  5.195000e+01  5.305000e+01  5.045000e+01  0.000000e+00
# 50%    1.666600e+02  1.675500e+02  1.711500e+02  1.634500e+02  4.900000e+01
# 75%    5.184000e+02  5.200000e+02  5.300000e+02  5.100000e+02  2.850000e+02
# max    1.001141e+05  1.000990e+05  1.008496e+05  9.971100e+04  1.000750e+05
#
#         close_price     avg_price  ttl_trd_qnty  turnover_lacs  no_of_trades  \
# count  1.408943e+06  1.408943e+06  1.408943e+06   1.408943e+06  1.408943e+06
# mean   6.843848e+02  6.853843e+02  1.650840e+06   3.563041e+03  1.179626e+04
# ...

# %%
data_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1408943 entries, 0 to 1408942
# Data columns (total 14 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   symbol         1408943 non-null  object
#  1   date           1408943 non-null  datetime64[ns]
#  2   prev_close     1408943 non-null  float64
#  3   open_price     1408943 non-null  float64
#  4   high_price     1408943 non-null  float64
#  5   low_price      1408943 non-null  float64
#  6   last_price     1408943 non-null  float64
#  7   close_price    1408943 non-null  float64
#  8   avg_price      1408943 non-null  float64
#  9   ttl_trd_qnty   1408943 non-null  int64
#  10  turnover_lacs  1408943 non-null  float64
#  11  no_of_trades   1408943 non-null  int64
#  12  deliv_qty      1408943 non-null  int64
#  13  deliv_per      1408943 non-null  float64
# dtypes: datetime64[ns](1), float64(9), int64(3), object(1)
# memory usage: 150.5+ MB

# %%
data_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 990833 entries, 0 to 990832
# Data columns (total 18 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   date                 990833 non-null  datetime64[ns]
#  1   symbol               990833 non-null  object
#  2   prev_close           990833 non-null  float64
#  3   open_price           990833 non-null  float64
#  4   high_price           990833 non-null  float64
#  5   low_price            990833 non-null  float64
#  6   last_price           990833 non-null  float64
#  7   close_price          990833 non-null  float64
#  8   avg_price            990833 non-null  float64
#  9   ttl_trd_qnty         990833 non-null  int64
#  10  turnover_lacs        990833 non-null  float64
#  11  no_of_trades         990833 non-null  int64
#  12  deliv_qty            990830 non-null  float64
#  13  deliv_per            990830 non-null  float64
# ...

# %%
data_2022.head()
# Out:
#         date      symbol  prev_close  open_price  high_price  low_price  \
# 0 2022-07-15   ALPSINDUS        2.40        2.50        2.50       2.50
# 1 2022-07-15  APOLSINHOT      622.00      614.30      622.00     613.00
# 2 2022-07-15   KAUSHALYA        3.65        3.80        3.80       3.80
# 3 2022-07-15      NBIFIN     1893.45     1885.00     1885.00    1861.50
# 4 2022-07-15  HECPROJECT       22.80       22.95       22.95      22.95
#
#    last_price  close_price  avg_price  ttl_trd_qnty  turnover_lacs  \
# 0        2.50         2.50       2.50          4972           0.12
# 1      621.90       621.95     613.48            40           0.25
# 2        3.80         3.80       3.80          7149           0.27
# 3     1861.50      1861.50    1878.29             7           0.13
# 4       22.95        22.95      22.95             1           0.00
#
#    no_of_trades  deliv_qty  deliv_per  date1 (year) date1 (quarter)  \
# ...

# %%
len((data_2022["symbol"].value_counts()==631))
# Out:
# 2073

# %%
len((data_2020["symbol"].value_counts()==857))
# Out:
# 2243

# %% [markdown]
# ### Working on Reliance

# %%
reliance = data_2020[data_2020.symbol=="RELIANCE"]
reliance.head()
# Out:
#         symbol       date  prev_close  open_price  high_price  low_price  \
# 1103  RELIANCE 2020-01-01     1514.05      1518.0     1527.10     1505.5
# 2587  RELIANCE 2021-01-01     1985.30      1988.0     1997.00     1982.0
# 4061  RELIANCE 2020-02-01     1411.65      1405.3     1426.95     1371.1
# 5504  RELIANCE 2021-02-01     1841.95      1859.4     1905.00     1848.0
# 7098  RELIANCE 2022-02-01     2386.60      2408.0     2420.60     2347.1
#
#       last_price  close_price  avg_price  ttl_trd_qnty  turnover_lacs  \
# 1103     1511.80      1509.60    1515.23       6402372       97010.63
# 2587     1988.00      1987.50    1989.50       4622002       91954.80
# 4061        0.00      1383.35    1402.89      11022901      154638.90
# 5504     1898.15      1895.30    1874.03      15774504      295618.21
# 7098        0.00      2378.70    2394.79       6092033      145891.70
#
#       no_of_trades  deliv_qty  deliv_per
# 1103        122265    1523290      23.79
# ...

# %%
reliance = reliance.sort_values('date')
reliance
# Out:
#           symbol       date  prev_close  open_price  high_price  low_price  \
# 1103    RELIANCE 2020-01-01     1514.05      1518.0     1527.10    1505.50
# 48609   RELIANCE 2020-01-02     1509.60      1512.0     1540.95    1512.00
# 95138   RELIANCE 2020-01-03     1535.30      1533.0     1541.65    1523.00
# 231204  RELIANCE 2020-01-06     1537.15      1520.0     1527.90    1498.00
# 279124  RELIANCE 2020-01-07     1501.50      1519.0     1534.50    1513.50
# ...          ...        ...         ...         ...         ...        ...
# 537113  RELIANCE 2023-06-12     2481.95      2475.5     2489.20    2465.00
# 582348  RELIANCE 2023-06-13     2484.15      2495.0     2523.45    2486.25
# 624701  RELIANCE 2023-06-14     2520.85      2521.0     2555.00    2517.00
# 675212  RELIANCE 2023-06-15     2551.85      2551.8     2562.55    2535.50
# 723242  RELIANCE 2023-06-16     2552.55      2560.2     2582.40    2560.20
#
# ...

# %%
reliance.date.value_counts()
# Out:
# 2021-11-03    2
# 2020-01-01    1
# 2022-04-29    1
# 2022-04-13    1
# 2022-04-18    1
#              ..
# 2021-02-25    1
# 2021-02-26    1
# 2021-03-01    1
# 2021-03-02    1
# 2023-06-16    1
# Name: date, Length: 856, dtype: int64

# %%
reliance = reliance.drop_duplicates()
reliance.date.value_counts()
# Out:
# 2020-01-01    1
# 2022-04-08    1
# 2022-04-12    1
# 2022-04-13    1
# 2022-04-18    1
#              ..
# 2021-02-25    1
# 2021-02-26    1
# 2021-03-01    1
# 2021-03-02    1
# 2023-06-16    1
# Name: date, Length: 856, dtype: int64

# %%
#Plotting the time series data
plt.figure(figsize=(15,10))
plt.plot(reliance.date, reliance.close_price ,label='Close Price')
plt.plot(reliance.date, reliance.close_price.rolling(window=3).mean(), label='3 day moving average')
plt.title('Reliability of Reliance Industries Limited')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.plot(reliance.date, reliance.close_price.rolling(window=3).std(), label='3 day moving std')
plt.title('Reliability of Reliance Industries Limited')
plt.xlabel('Date')
plt.ylabel('3 day moving std')
plt.show()
